# %% [markdown]
# # Week 3 - Classification
#
# This week, we shift from gathering human textual classifications through crowdsourcing, to using machine learning models and algorithms that train on those human classifications and extend them to documents far too numerous to read. If you recall, *clustering* allows us to stably partition text data (e.g., documents, turns of conversation) according to all patterns of covariation among available text features. *Classification*, by contrast, partitions text data according to only those features and their variation that enable us to mimic and extrapolate human annotations.
#
# In this notebook, we will show how to use a variety of classification methods, including Naïve Bayes, Logistic regression, K-nearest neighbor, decision trees and random forests, support vector machines and even a simple neural network, the perceptron. We will also demonstrate ensemble techniques that can link several such methods into a single, more accurate, classification pipeline. We will finally learn to use conventions and metrics to evaluate classifier performance on out-of-sample data.
#
# For this notebook we will be using the following packages.

# %%
#Special module written for this class
#This provides access to data and to helper functions from previous weeks
#Make sure you update it before starting this notebook
import lucem_illud_2020 #pip install -U git+git://github.com/Computational-Content-Analysis-2020/lucem_illud_2020.git

#All these packages need to be installed from pip
#For ML
import sklearn
import sklearn.naive_bayes
import sklearn.tree
import sklearn.ensemble
import sklearn.neural_network
import sklearn.decomposition

import nltk #For tokenizing and normalizing
import numpy as np #arrays
import matplotlib.pyplot as plt #Plots
import matplotlib.colors # For nice colours
import seaborn #Makes plots look nice, also heatmaps
import scipy as sp #for interp

#These are from the standard library
import collections
import os
import os.path
import random
import re
import glob
import pandas
import requests
import json
import math

#This 'magic' command makes the plots work better
#in the notebook, don't use it outside of a notebook.
#Also you can ignore the warning
# %matplotlib inline

# %% [markdown]
# # Simple Simulated Examples
#
# Here we create a sandbox for you to explore different types of classified data and how different statistical classifiers perform on each type.

# %% [markdown]
# ## Generating example data
#
# We start by loading one of the "cartoon" or simplified data sets and then dividing it into training and testing sets. To maximize our ability to visualize, each dataset involves two classes, colored yellow and blue, arrayed along two two dimensions (`x` and `y`).
#
# The four data patterns include:
# + `random` in which the two classes are randomly distributed across both dimensions
# + `andSplit` in which the two classes are linearly split along one of two dimensions (e.g., men like Adidas)
# + `xorSplit` in which the two classes are split, oppositely, along each dimension (e.g., old ladies and young men like Nikes)
# + `targetSplit` in which one class is nested within the other in two dimensions (e.g., middle aged, middle income people like vintage Mustangs)
# + `multiBlobs` in which 5 classes are placed as bivariate Gaussians at random locations
#
# `noise` is a variable [0-1] that ranges from no noise in the prescribed pattern [0] to complete noise/randomness [1].
#
# Uncomment (remove the # in front of) each dataset, one at a time, and then run the cell and subsequent cells to examine how each machine learning approach captures each pattern.

# %%
noise = .2

#dfTrain, dfTest = lucem_illud_2020.trainTestSplit(lucem_illud_2020.random())
#dfTrain, dfTest = lucem_illud_2020.trainTestSplit(lucem_illud_2020.andSplit(noise))
#dfTrain, dfTest = lucem_illud_2020.trainTestSplit(lucem_illud_2020.xorSplit(noise)) #Please try this one
#dfTrain, dfTest = lucem_illud_2020.trainTestSplit(lucem_illud_2020.targetSplit(noise))
#dfTrain, dfTest = lucem_illud_2020.trainTestSplit(lucem_illud_2020.multiBlobs(noise))

# %%
noise = .2

#dfTrain, dfTest = lucem_illud_2020.trainTestSplit(lucem_illud_2020.random())
#dfTrain, dfTest = lucem_illud_2020.trainTestSplit(lucem_illud_2020.andSplit(noise))
#dfTrain, dfTest = lucem_illud_2020.trainTestSplit(lucem_illud_2020.xorSplit(noise)) #Please try this one
dfTrain, dfTest = lucem_illud_2020.trainTestSplit(lucem_illud_2020.targetSplit(noise))
#dfTrain, dfTest = lucem_illud_2020.trainTestSplit(lucem_illud_2020.multiBlobs(noise))

# %% [markdown]
# We can easily visualize the rendered datasets because they are generated in two dimensions.

# %%
lucem_illud_2020.plotter(dfTrain)
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %% [markdown]
# ## Training a Machine Learning algorithm
#
# We can now pick a model, there are many more options in `scikit-learn`. These are just a few examples, which array along the machine learning "tribes" described in Pedro Domingos _The Master Algorithm_.
#
# Uncomment (remove the # in front of) each algorithm one at a time, then run the cell and subsequent cells to evaluate how it learns to understand the data.

# %%
#Bayes
#clf = sklearn.naive_bayes.GaussianNB()

#Analogizes
#clf = sklearn.svm.SVC(kernel = 'linear', probability = True) #slow, set probability = False to speed up
#clf = sklearn.svm.SVC(kernel = 'poly', degree = 3, probability = True) #slower
#clf = sklearn.neighbors.KNeighborsClassifier(5, weights='distance')# k, 'distance' or 'uniform'

#Classical Regression
#clf = sklearn.linear_model.LogisticRegression()

#Symbolists
#clf = sklearn.tree.DecisionTreeClassifier()
#clf = sklearn.ensemble.RandomForestClassifier()

#Connectionists
#clf = sklearn.neural_network.MLPClassifier()

#Ensemble
#clf = sklearn.ensemble.GradientBoostingClassifier()

# %%
#Bayes
#clf = sklearn.naive_bayes.GaussianNB()

#Analogizes
#clf = sklearn.svm.SVC(kernel = 'linear', probability = True) #slow, set probability = False to speed up
#clf = sklearn.svm.SVC(kernel = 'poly', degree = 3, probability = True) #slower
#clf = sklearn.neighbors.KNeighborsClassifier(5, weights='distance')# k, 'distance' or 'uniform'

#Classical Regression
#clf = sklearn.linear_model.LogisticRegression()

#Symbolists
#clf = sklearn.tree.DecisionTreeClassifier()
#clf = sklearn.ensemble.RandomForestClassifier()

#Connectionists
#clf = sklearn.neural_network.MLPClassifier()

#Ensemble
clf = sklearn.ensemble.GradientBoostingClassifier()

# %% [markdown]
# Now we fit the model by giving it our training data

# %%
clf.fit(np.stack(dfTrain['vect'], axis=0), dfTrain['category'])
# Out:
# GradientBoostingClassifier(criterion='friedman_mse', init=None,
#                            learning_rate=0.1, loss='deviance', max_depth=3,
#                            max_features=None, max_leaf_nodes=None,
#                            min_impurity_decrease=0.0, min_impurity_split=None,
#                            min_samples_leaf=1, min_samples_split=2,
#                            min_weight_fraction_leaf=0.0, n_estimators=100,
#                            n_iter_no_change=None, presort='auto',
#                            random_state=None, subsample=1.0, tol=0.0001,
#                            validation_fraction=0.1, verbose=0,
#                            warm_start=False)

# %% [markdown]
# ## Algorithm evaluation
#
# We can look at few measurements of each classifier's performance by using the testing set

# %%
lucem_illud_2020.evaluateClassifier(clf, dfTest)
# Out:
#           Error_Rate      AUC  Precision  Average_Precision    Recall
# Category
# 0               0.13  0.87166   0.902913           0.850375  0.853211
# 1               0.13  0.87166   0.835052           0.793288  0.890110

# %% [markdown]
# This lets us look at which classes do better:

# %%
lucem_illud_2020.plotConfusionMatrix(clf, dfTest)

# %% [markdown]
# The greater the area under the curve the better.

# %%
lucem_illud_2020.plotMultiROC(clf, dfTest)

# %% [markdown]
# We can also look at the regions the classifer identifies as one class or the other:

# %%
lucem_illud_2020.plotregions(clf, dfTrain)
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %% [markdown]
# ## Now we do the same for real data
#
# Available data sets include:
# + Reddit threads "classified" by thread topic
# + 20 newsgroups "classified" by group topic
# + Senate press releases "classified" by Senator (2 senators)
# + Senate press releases "classified" by Senator (5 senators)
# + Emails classified as Spam or Ham

# %%
dfTrain, dfTest = lucem_illud_2020.trainTestSplit(lucem_illud_2020.loadReddit())
#dfTrain, dfTest = lucem_illud_2020.trainTestSplit(lucem_illud_2020.loadNewsGroups())
#dfTrain, dfTest = lucem_illud_2020.trainTestSplit(lucem_illud_2020.loadSenateSmall())
#dfTrain, dfTest = lucem_illud_2020.trainTestSplit(lucem_illud_2020.loadSenateLarge())
#dfTrain, dfTest = lucem_illud_2020.trainTestSplit(lucem_illud_2020.loadSpam())
# Out:
# Loading Reddit data
# Converting to vectors

# %%
#Bayes
clf = sklearn.naive_bayes.GaussianNB()

#Analogizes
#clf = sklearn.svm.SVC(kernel = 'linear', probability = True) #slow, set probability = False to speed up, but lose ROC
#clf = sklearn.svm.SVC(kernel = 'poly', degree = 3, probability = True) #slower
#clf = sklearn.neighbors.KNeighborsClassifier(5, weights='distance')# k, 'distance' or 'uniform'

#Classical Regression
#clf = sklearn.linear_model.LogisticRegression()

#Symbolists
#clf = sklearn.tree.DecisionTreeClassifier()
#clf = sklearn.ensemble.RandomForestClassifier()

#Connectionists
#clf = sklearn.neural_network.MLPClassifier()

#Ensemble
#clf = sklearn.ensemble.GradientBoostingClassifier()

# %%
clf.fit(np.stack(dfTrain['vect'], axis=0), dfTrain['category'])
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)

# %%
lucem_illud_2020.evaluateClassifier(clf, dfTest)
# Out:
#                          Error_Rate       AUC  Precision  Average_Precision  \
# Category
# Weeaboo Tales              0.184953  0.845866   0.551724           0.519272
# Tales From Tech Support    0.078370  0.874139   0.915493           0.767978
# Relationships              0.144201  0.762000   0.728814           0.523345
# Bad Roommates              0.137931  0.801162   0.821918           0.639103
#
#                            Recall
# Category
# Weeaboo Tales            0.901408
# Tales From Tech Support  0.773810
# Relationships            0.589041
# Bad Roommates            0.659341

# %%
lucem_illud_2020.plotConfusionMatrix(clf, dfTest)

# %%
lucem_illud_2020.plotMultiROC(clf, dfTest)

# %%
lucem_illud_2020.plotregions(clf, dfTrain)
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# ...

# %% [markdown]
# ## <span style="color:red">*Exercise 1*</span>
#
# <span style="color:red">Go back through all of the cells above and generate 10 distinct artificial datasets and classify them with all of the available methods. Add a cell immediately below and describe which classifier(s) worked best with which artificially constructed data source and why. Then go through all of the empirical datasets (i.e., Newsgroups, Senate Small, Senate Large, Email Spam) and classify them with all available methods. Add a second cell immediately below and describe which classifier(s) worked best with which data set and why.
#
# <span style="color:red">***Stretch*** (but also required) Wander through the SKLearn documentation available [here](http://scikit-learn.org/stable/), particularly perusing the classifiers. In cells following, identify and implement a new classifier that we have not yet used (e.g., AdaBoost, CART) on one artificial dataset and one real dataset (used above). Then, in the next cell describe the classifier, detail how it compares with the approaches above, and why it performed better or worse than others.

# %%
#generate 10 distinct artificial datasets and classify them with all of the available methods
noise = .2
#datasets
datasets ={
    'random1': lucem_illud_2020.random(),
    'random2': lucem_illud_2020.andSplit(noise),
    'andSplit1': lucem_illud_2020.andSplit(noise),
    'andSplit2': lucem_illud_2020.andSplit(noise*2),
    'XorSplit1': lucem_illud_2020.xorSplit(noise),
    'XorSplit2': lucem_illud_2020.xorSplit(noise*2),
    'TargetSplit1': lucem_illud_2020.targetSplit(noise),
    'TargetSplit2': lucem_illud_2020.targetSplit(noise * 2),
    'multiblobs1': lucem_illud_2020.multiBlobs(noise),
    'multiblobs2': lucem_illud_2020.multiBlobs(noise*2)
}
classifiers ={'Naive Bayes': sklearn.naive_bayes.GaussianNB(),
              'SVM with linear kernel': sklearn.svm.SVC(kernel = 'linear', probability = True),
              'SVM with poly kernel': sklearn.svm.SVC(kernel = 'poly', degree = 3, probability = True),
              'KNN with 5 neighbors': sklearn.neighbors.KNeighborsClassifier(5, weights='distance'),
              'classical regression': sklearn.linear_model.LogisticRegression(),
              'decision tree': sklearn.tree.DecisionTreeClassifier(),
              'random forest': sklearn.ensemble.RandomForestClassifier(),
              'neural network': sklearn.neural_network.MLPClassifier(),
              'ensemble gradient boost': sklearn.ensemble.GradientBoostingClassifier()
             }

for ds in datasets:
    print('\n*****Datasets:{}*****'.format(ds))
    dfTrain, dfTest = lucem_illud_2020.trainTestSplit(datasets[ds])#split datasets into training and testing data sets
   
    for classifier in classifiers:   
        clf = classifiers [classifier]
        print('-----------------------------------')   
        print('Evaluating {}'.format(classifier))
        clf.fit(np.stack(dfTrain['vect'], axis=0), dfTrain['category'])
        print(lucem_illud_2020.evaluateClassifier(clf, dfTest))
# Out:
# *****Datasets:random1*****
# -----------------------------------
# Evaluating Naive Bayes
#           Error_Rate       AUC  Precision  Average_Precision    Recall
# Category
# 0              0.535  0.468872   0.460317           0.470241  0.597938
# 1              0.535  0.468872   0.472973           0.500719  0.339806
# -----------------------------------
# Evaluating SVM with linear kernel
#           Error_Rate       AUC  Precision  Average_Precision    Recall
# Category
# 0              0.525  0.476179   0.462963           0.473641  0.515464
# 1              0.525  0.476179   0.489130           0.503698  0.436893
# -----------------------------------
# Evaluating SVM with poly kernel
#           Error_Rate       AUC  Precision  Average_Precision    Recall
# Category
# 0              0.505  0.502202   0.486486           0.486103  0.742268
# 1              0.505  0.502202   0.519231           0.516109  0.262136
# -----------------------------------
# Evaluating KNN with 5 neighbors
# ...

# %% [markdown]
# For random 1 dataset with no noise, none of the classification models work well since all models have an error rate around 50% and most of the AUC are below or around 50%.
#
# For random 2 dataset with noise=0.2, all the models seem to perform well with the SVM model with the decision tree model having teh lowest error rate and highest AUC.
#
# For dataset andSplit 1 (with noise=0.2),Naive Bayes, classical regression, and the neural networks model seem to perform better than the rest. All three of them have an error rate around 0.085 and AUC of 0.915466.
#
# For dataset andSplit 2 (with noise=0.4),all of the models' error increased to around or above 0.2. Neural nework model and classical regression model seem to be performing a little bit better than the rest with an error rate of 0.2 and AUC of 0.801003.
#
# For datasets XorSplit 1 (with noise=0.2), Naive Bayes and classical regression are the worst performing models, both with an error rate of 0.515. Neural network model seems to be the winner with an error rate of 0.15 and AUC of 0.85.
#
# For datasets XorSplit 2 (with noise=0.4), Naive Bayes, SVM with linear kernel, and the classical regression models don't do well, all having an error rate around 0.50. Neural network model seems to be the winner with an error rate of 0.195 and AUC of 0.806022.
#
# For TargetSplit1 (with noise = 0.2), all of the models are doing well with an error rate around 0.125 except for SVM with linear kernel, SVM with poly kernel, and the classical regression model.
#
# For RargetSplit2 (with noise = 0.4), surprisingly, naive bayes outperforms all the rest!
#
# For multiblob1 (with noise = 0.2), all of the models are performing well. SVM seems to be the best with no error rate and a 1.0 AUC.
#
# For Multiblob2 (with noise =0.4), all of the modesl seem to have similar performance.

# %%
datasets2 = {'Reddit': lucem_illud_2020.loadReddit(),
             'NewsGroups': lucem_illud_2020.loadNewsGroups(),
             'SenateSmall': lucem_illud_2020.loadSenateSmall(),
             'SenateLarge': lucem_illud_2020.loadSenateLarge(),
             'Spam': lucem_illud_2020.loadSpam()
    
}

classifiers ={'Naive Bayes': sklearn.naive_bayes.GaussianNB(),
              'SVM with linear kernel': sklearn.svm.SVC(kernel = 'linear', probability = True),
              'SVM with poly kernel': sklearn.svm.SVC(kernel = 'poly', degree = 3, probability = True),
              'KNN with 5 neighbors': sklearn.neighbors.KNeighborsClassifier(5, weights='distance'),
              'classical regression': sklearn.linear_model.LogisticRegression(),
              'decision tree': sklearn.tree.DecisionTreeClassifier(),
              'random forest': sklearn.ensemble.RandomForestClassifier(),
              'neural network': sklearn.neural_network.MLPClassifier(),
              'ensemble gradient boost': sklearn.ensemble.GradientBoostingClassifier()
             }

for ds in datasets2:
    print('\n*****Datasets:{}*****'.format(ds))
    dfTrain, dfTest = lucem_illud_2020.trainTestSplit(datasets2[ds])#split datasets into training and testing data sets
   
    for classifier in classifiers:   
        clf = classifiers [classifier]
        print('-----------------------------------')   
        print('Evaluating {}'.format(classifier))
        clf.fit(np.stack(dfTrain['vect'], axis=0), dfTrain['category'])
        print(lucem_illud_2020.evaluateClassifier(clf, dfTest))
# Out:
# Loading Reddit data
# Converting to vectors
# Loading data for: comp.sys.mac.hardware
# Loading data for: comp.windows.x
# Loading data for: misc.forsale
# Loading data for: rec.autos
# Converting to vectors
# Loading senate data
# Converting to vectors
# Loading senator: Klobuchar
# Loading senator: Kyl
# Loading senator: Kerry
# Loading senator: Kohl
# Loading senator: Kennedy
# Converting to vectors
# Loading Spam
# Loading Ham
# Converting to vectors
#
# *****Datasets:Reddit*****
# -----------------------------------
# Evaluating Naive Bayes
#                          Error_Rate       AUC  Precision  Average_Precision  \
# Category
# Weeaboo Tales              0.194357  0.860781   0.512397           0.498152
# Bad Roommates              0.163009  0.766475   0.694444           0.528072
# Relationships              0.150470  0.738467   0.769231           0.517711
# Tales From Tech Support    0.100313  0.848093   0.945946           0.763450
#
#                            Recall
# ...

# %% [markdown]
# For the Reddit dataset, the SVM with linear kernel model and neural network models seem to be the winners. Both models have the lowest error rates (around 0.01 or even lower) and their AUC ranges from 0.977 to 0.9923. Gradient boost model is also doing great with a slightly higher error rate (0.015674 to 0.025078).
#
# For the NewsGroup dataset, SVM with linear kernel (error rate: 0.029787 to 0.068), classical regression (error rate: from 0.03 to 0.08), and the neural network model (error rate 0.025 to 0.082) all have an error rate below 0.1.
#
# For the SenateSmall dataset, SVM with linear kernel is doing particularly well with error rate around 0.005865. Also, the decision tree, random forest models, as well as ensemble gradient boost model are also performing well with error rate below 0.0088. In fact, every model seems to work fine except for SVM with poly kernel (it has an error rate at around 0.43).
#
# For the SenateLarge dataset, every model seems to perform well with error rate below or around 0.1 except for SVM with poly kernel (with error rate ranges from 0.085897 to 0.55).
#
# For the Spam dataset, again, SVM with poly kernel is performing poorly. The neural network model seems to be the winner with the lowest error rate (=0.08333) and the highest AUC (=0.836632).

# %%
#In cells following, identify and implement a new classifier that we have not yet used (e.g., AdaBoost, CART) on one artificial dataset and one real dataset (used above)

#adaboost classifier
noise = 0.2
print("******Adaboost classifier with artificial dataset: TargetSplit1*****")
dfTrain, dfTest = lucem_illud_2020.trainTestSplit(lucem_illud_2020.targetSplit(noise))
clf = sklearn.ensemble.AdaBoostClassifier()
clf.fit(np.stack(dfTrain['vect'], axis=0), dfTrain['category'])
print(lucem_illud_2020.evaluateClassifier(clf, dfTest))
lucem_illud_2020.plotConfusionMatrix(clf, dfTest)
lucem_illud_2020.plotMultiROC(clf, dfTest)

print("-----------------------")
print("*****Adaboost classifer with Newsgroup data*****")
dfTrain, dfTest = lucem_illud_2020.trainTestSplit(lucem_illud_2020.loadNewsGroups())
clf = sklearn.ensemble.AdaBoostClassifier()
clf.fit(np.stack(dfTrain['vect'], axis=0), dfTrain['category'])
print(lucem_illud_2020.evaluateClassifier(clf, dfTest))
lucem_illud_2020.plotConfusionMatrix(clf, dfTest)
lucem_illud_2020.plotMultiROC(clf, dfTest)
# Out:
# ******Adaboost classifier with artificial dataset: TargetSplit1*****
#           Error_Rate       AUC  Precision  Average_Precision    Recall
# Category
# 0               0.12  0.882612   0.827273           0.809186  0.947917
# 1               0.12  0.882612   0.944444           0.866902  0.817308
# -----------------------
# *****Adaboost classifer with Newsgroup data*****
# Loading data for: comp.sys.mac.hardware
# Loading data for: comp.windows.x
# Loading data for: misc.forsale
# Loading data for: rec.autos
# Converting to vectors
#                        Error_Rate       AUC  Precision  Average_Precision  \
# Category
# comp.sys.mac.hardware    0.131915  0.808116   0.794393           0.625293
# misc.forsale             0.151064  0.763302   0.771739           0.559222
# rec.autos                0.191489  0.804900   0.561290           0.494811
# comp.windows.x           0.091489  0.877710   0.810345           0.707050
#
#                          Recall
# Category
# ...

# %% [markdown]
# For the targetsplit 1 dataset, if we were to compare adboost with other models, it seems adboost performs a little bit better than the decision tree model but adboost is not as good as Naive Bayes, random forest, or nerual network, all of which having an error rate below 0.12.
#
# For the Newsgroup data set, adboost model has a performance similar to the Naive Bayes model, but it is not as good as the SVM with linear kernel model, the classical regression model, and the neural network model (the three all have an error rate below 0.1).

# %% [markdown]
# # Clinton / Obama Press Releases
#
# We often will not have nicely prepared data, so we will work though the proccess of cleaning and structuring in more detail here:
#
# While the Clinton and Obama Senatorial Press Releases are not hand-coded, we can imagine that we have been given a stack of such press releases, but lost the metadata associated with which senatorial office issued which. If we label a few of them, how well can our classifier do at recovering the rest?

# %%
ObamaClintonReleases = pandas.read_csv('../data/ObamaClintonReleases.csv', index_col=0)

# %% [markdown]
# Let's turn the 'targetSenator' column into a binary category variable.

# %%
ObamaClintonReleases['category'] = [s == 'Obama' for s in ObamaClintonReleases['targetSenator']]

# %% [markdown]
# Tokenize and normalize

# %%
ObamaClintonReleases['tokenized_text'] = ObamaClintonReleases['text'].apply(lambda x: lucem_illud_2020.word_tokenize(x))
ObamaClintonReleases['normalized_text'] = ObamaClintonReleases['tokenized_text'].apply(lambda x: lucem_illud_2020.normalizeTokens(x))

# %% [markdown]
# Let's split the data into training data and testing data.

# %%
holdBackFraction = .2
train_data_df, test_data_df = lucem_illud_2020.trainTestSplit(ObamaClintonReleases, holdBackFraction=holdBackFraction)

# %%
print(len(train_data_df))
print(len(test_data_df))
# Out:
# 1368
# 341

# %% [markdown]
# ## Logistic Regression

# %% [markdown]
# First, let's try with a logistic regression, which may be familiar to you from statistical methods classes. First, we must turn the training dataset into a tf-idf matrix (`lucem_illud_2020.generateVecs()` will help with this but for now we are doing it the long way):

# %%
TFVectorizer = sklearn.feature_extraction.text.TfidfVectorizer(max_df=100, min_df=2, stop_words='english', norm='l2')
TFVects = TFVectorizer.fit_transform(train_data_df['text'])

# %% [markdown]
# Note that we can use the CountVectorizer instead, which simply produces a matrix of word counts.

# %%
TFVects.shape
# Out:
# (1368, 11347)

# %% [markdown]
# We can save this in the dataframe to make things easier

# %%
train_data_df['vect'] = [np.array(v).flatten() for v in TFVects.todense()]

# %% [markdown]
# In a regression, we cannot have more variables than cases. So, we need to first do a dimension reduction. First, we will approah this with PCA. You have previously seen this in week 3. Here we are not concerned about visualization, but rather classification and so all principal components are calculated. Watch out: we have to use `stack` not `sum` for combining the vectors. We note that you could also use topic loading and embedding dimensions as featured variables.

# %%
pca = sklearn.decomposition.PCA()
reduced_data = pca.fit_transform(np.stack(train_data_df['vect'], axis=0))

# %% [markdown]
# We can store the PCA space vectors in the dataframe too:

# %%
train_data_df['pca'] = [r for r in reduced_data]

# %% [markdown]
# Visualization in 2D:

# %%
fig, ax = plt.subplots(figsize = (10,10))
ax.axis('off')
pallet = seaborn.color_palette(palette='coolwarm', n_colors = 2)

#Plot Obama
a = np.stack(train_data_df[train_data_df['category']]['pca'])
ax.scatter(a[:,0], a[:, 1], c = pallet[0], label = "True")

#Plot not Obama
a = np.stack(train_data_df[train_data_df['category'].eq(False)]['pca'])
ax.scatter(a[:,0], a[:, 1], c = pallet[1], label = "False")
    
ax.legend(loc = 'upper right', title = 'Is Obama')
plt.title('True Classes, Training Set')
plt.show()
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %% [markdown]
# PCA cannot distinguish Obama very well. Let's perform a screeplot to see how many Principal Components we need.

# %%
n = len(train_data_df)

fig, (ax1, ax2, ax3) = plt.subplots(ncols=3, figsize = (16, 5), sharey=True)

eigen_vals = np.arange(n) + 1
ax1.plot(eigen_vals, pca.explained_variance_ratio_, 'ro-', linewidth=1)
ax1.set_title('Scree Plot (Full)')
ax1.set_xlabel('Principal Component')
ax1.set_ylabel('Proportion of Explained Variance')

eigen_vals = np.arange(50) + 1
ax2.plot(eigen_vals, pca.explained_variance_ratio_[:50], 'ro-', linewidth=1)
ax2.set_title('Scree Plot (First 50 Principal Components)')
ax2.set_xlabel('Principal Component')
ax2.set_ylabel('Proportion of Explained Variance')


eigen_vals = np.arange(20) + 1
ax3.plot(eigen_vals, pca.explained_variance_ratio_[:20], 'ro-', linewidth=2)
ax3.set_title('Scree Plot (First 50 Principal Components)')
ax3.set_xlabel('Principal Component')
ax3.set_ylabel('Proportion of Explained Variance')

plt.show()

# %% [markdown]
# Let's choose the first 10 pricipal components as our covariates.

# %%
train_data_df['pca_reduced_10'] = train_data_df['pca'].apply(lambda x: x[:10])

# %% [markdown]
# Now we fit a logistic regression to our data.

# %%
logistic = sklearn.linear_model.LogisticRegression()
logistic.fit(np.stack(train_data_df['pca_reduced_10'], axis=0), train_data_df['category'])
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %% [markdown]
# Let's see how the logistic regression performs on the training dataset from which we develop the model. Unfortunately, the mean accuracy is only about 64%.

# %%
logistic.score(np.stack(train_data_df['pca_reduced_10'], axis=0), train_data_df['category'])
# Out:
# 0.6834795321637427

# %% [markdown]
# How does it perform on the testing dataset, which we "held out" and did not use for model training? We need to repeat all the steps on the testing data, but without retraining:

# %%
#Create vectors
TFVects_test = TFVectorizer.transform(test_data_df['text'])
test_data_df['vect'] = [np.array(v).flatten() for v in TFVects_test.todense()]

#PCA
reduced_data_test = pca.transform(np.stack(test_data_df['vect'], axis=0))
test_data_df['pca'] = [r for r in reduced_data_test]
test_data_df['pca_reduced_10'] = test_data_df['pca'].apply(lambda x: x[:10])

#Test
logistic.score(np.stack(test_data_df['pca_reduced_10'], axis=0), test_data_df['category'])
# Out:
# 0.6510263929618768

# %% [markdown]
# Slightly poorer. How about using more dimensions (40)?

# %%
train_data_df['pca_reduced_40'] = train_data_df['pca'].apply(lambda x: x[:40])
test_data_df['pca_reduced_40'] = test_data_df['pca'].apply(lambda x: x[:40])

logistic.fit(np.stack(train_data_df['pca_reduced_40'], axis=0), train_data_df['category'])

print("Training:")
print(logistic.score(np.stack(train_data_df['pca_reduced_40'], axis=0), train_data_df['category']))
print("Testing:")
print(logistic.score(np.stack(test_data_df['pca_reduced_40'], axis=0), test_data_df['category']))
# Out:
# Training:
# 0.7368421052631579
# Testing:
# 0.6803519061583577

# %% [markdown]
# Or still more (100)?

# %%
train_data_df['pca_reduced_100'] = train_data_df['pca'].apply(lambda x: x[:100])
test_data_df['pca_reduced_100'] = test_data_df['pca'].apply(lambda x: x[:100])

logistic.fit(np.stack(train_data_df['pca_reduced_100'], axis=0), train_data_df['category'])

print("Training:")
print(logistic.score(np.stack(train_data_df['pca_reduced_100'], axis=0), train_data_df['category']))
print("Testing:")
print(logistic.score(np.stack(test_data_df['pca_reduced_100'], axis=0), test_data_df['category']))
# Out:
# Training:
# 0.8216374269005848
# Testing:
# 0.7741935483870968

# %% [markdown]
# Or even more (200)!

# %%
train_data_df['pca_reduced_200'] = train_data_df['pca'].apply(lambda x: x[:200])
test_data_df['pca_reduced_200'] = test_data_df['pca'].apply(lambda x: x[:200])

logistic.fit(np.stack(train_data_df['pca_reduced_200'], axis=0), train_data_df['category'])

print("Training:")
print(logistic.score(np.stack(train_data_df['pca_reduced_200'], axis=0), train_data_df['category']))
print("Testing:")
print(logistic.score(np.stack(test_data_df['pca_reduced_200'], axis=0), test_data_df['category']))
# Out:
# Training:
# 0.8669590643274854
# Testing:
# 0.8005865102639296

# %% [markdown]
# This is becoming ridiculous (400)!

# %%
train_data_df['pca_reduced_400'] = train_data_df['pca'].apply(lambda x: x[:400])
test_data_df['pca_reduced_400'] = test_data_df['pca'].apply(lambda x: x[:400])

logistic.fit(np.stack(train_data_df['pca_reduced_400'], axis=0), train_data_df['category'])

print("Training:")
print(logistic.score(np.stack(train_data_df['pca_reduced_400'], axis=0), train_data_df['category']))
print("Testing:")
print(logistic.score(np.stack(test_data_df['pca_reduced_400'], axis=0), test_data_df['category']))
# Out:
# Training:
# 0.9173976608187134
# Testing:
# 0.8328445747800587

# %% [markdown]
# Increasing the number of covariates would overfit our data, and it seems that using a logistic regression, our prediction accuracy is at best about 65%. We can, however, try a logistic regression that uses the TF-IDF scores for each word, but with an L1 regularization or L1-norm loss function, which is also known as least absolute deviations (LAD), least absolute errors (LAE) or L1 penalty. It minimizes the sum of the absolute differences (S) between the target value ($Y_i$) and the estimated values ($f(x_i)$) and prunes all insignificant variables (i.e., word TF-IDF scores):
#
# $S=\sum^n_{i=1}|y_i=f(x_i)|$
#
# The result is a model retaining only the most individually significant features.

# %%
logistic_l1= sklearn.linear_model.LogisticRegression(penalty='l2')
logistic_l1.fit(np.stack(train_data_df['vect'], axis=0), train_data_df['category'])
print(logistic_l1.score(np.stack(train_data_df['vect'], axis=0), train_data_df['category']))
# Out:
# 0.9597953216374269

# %% [markdown]
# Train the model using training data, and then test it on the testing data.

# %%
print(logistic_l1.score(np.stack(test_data_df['vect'], axis=0), test_data_df['category']))
# Out:
# 0.8328445747800587

# %% [markdown]
# 81% accuracy seems like the best we can get by using a logistic regression.
#
# Now let's try with Naive Bayes. Classically, it is trained with word counts, but TF-IDF vectors are also quite good:

# %%
naiveBayes = sklearn.naive_bayes.BernoulliNB()
naiveBayes.fit(np.stack(train_data_df['vect'], axis=0), train_data_df['category'])
# Out:
# BernoulliNB(alpha=1.0, binarize=0.0, class_prior=None, fit_prior=True)

# %%
print("Training:")
print(naiveBayes.score(np.stack(train_data_df['vect'], axis=0), train_data_df['category']))
print("Testing:")
print(naiveBayes.score(np.stack(test_data_df['vect'], axis=0), test_data_df['category']))
# Out:
# Training:
# 0.9641812865497076
# Testing:
# 0.8680351906158358

# %% [markdown]
# A bit better than the logit, but that's just looking at the accuracy. What about other measures? Let's first save the predictions in the dataframe to save use rerunning the model every time:

# %%
test_data_df['nb_predict'] = naiveBayes.predict(np.stack(test_data_df['vect'], axis=0))
test_data_df['nb_predict_prob_true'] = naiveBayes.predict_proba(np.stack(test_data_df['vect'], axis=0))[:,0] #other is prop false

# %% [markdown]
# Precision:

# %%
sklearn.metrics.precision_score(test_data_df['nb_predict'], test_data_df['category'])
# Out:
# 0.8251748251748252

# %% [markdown]
# Recall:

# %%
sklearn.metrics.recall_score(test_data_df['nb_predict'], test_data_df['category'])
# Out:
# 0.855072463768116

# %% [markdown]
# F1-measure:

# %%
sklearn.metrics.f1_score(test_data_df['nb_predict'], test_data_df['category'])
# Out:
# 0.8398576512455517

# %% [markdown]
# Let's take a look at how well our posterior distribution looks relative to the truth.

# %%
fig, ax = plt.subplots()
ax.grid(False)
ax.set_frame_on(False)
test_data_df[test_data_df['category'].eq(True)]['nb_predict_prob_true'].hist(alpha = 0.5, ax = ax, bins = 10, label = 'True', color = 'red')
test_data_df[test_data_df['category'].eq(False)]['nb_predict_prob_true'].hist(alpha = 0.5, ax = ax, bins = 10, label = 'False', color = 'blue')
ax.set_xlim((0,1.1))
ax.legend(title = "Is Obama")
ax.set_xlabel('posterior')
ax.set_ylabel('counts')
plt.show()

# %% [markdown]
# The classification is suprisingly accurate. We can even look at what words are most influential with a bit of simple math:

# %%
#Top indices
trueVals, falseVals = naiveBayes.feature_log_prob_

words_dict = {
    'Obama' : [],
    'Obama_log_prob' : [],
    'Clinton' : [],
    'Clinton_log_prob' : [],
}

for i, prob in sorted(enumerate(trueVals), key = lambda x:x[1], reverse=True)[:15]:
    words_dict['Obama'].append(TFVectorizer.get_feature_names()[i])
    words_dict['Obama_log_prob'].append(prob)

for i, prob in sorted(enumerate(falseVals), key = lambda x:x[1], reverse=True)[:15]:
    words_dict['Clinton'].append(TFVectorizer.get_feature_names()[i])
    words_dict['Clinton_log_prob'].append(prob)
    
pandas.DataFrame(words_dict)
# Out:
#          Obama  Obama_log_prob    Clinton  Clinton_log_prob
# 0    signature       -2.235252       5566         -1.736951
# 1       island       -2.295150       dick         -1.864785
# 2           fy       -2.332890     monday         -1.864785
# 3     welcomed       -2.332890        amy         -1.923281
# 4         read       -2.372111   brundage         -1.972674
# 5       urging       -2.372111    chicago         -2.051662
# 6      awarded       -2.399140  temporary         -2.214987
# 7       entire       -2.412933    writing         -2.214987
# 8      welcome       -2.412933     reform         -2.231248
# 9       ground       -2.426919   location         -2.264584
# 10       honor       -2.441104  political         -2.264584
# 11       class       -2.455493         va         -2.299070
# 12    expected       -2.455493      cases         -2.316770
# 13       urban       -2.455493    quickly         -2.316770
# 14  supporting       -2.470092  practices         -2.334788

# %% [markdown]
# ## Multinomial Naive Bayes

# %% [markdown]
# What if we want to classify our text into one of *many* classes? The multinomial Naive Bayes generating model assumes that document features (e.g., words) are generated by draws from a multinomial distribution (recall this gives the probability to observe a particular pattern of counts across features).
#
# Let's use again the dataset we used in week 3, the 20 newsgroup dataset.

# %%
newsgroups = sklearn.datasets.fetch_20newsgroups(data_home = '../data') #Free data to play with: documents from a newsgroup corpus.
newsgroups.target_names #Possible categories, i.e., the newsgroups
# Out:
# ['alt.atheism',
#  'comp.graphics',
#  'comp.os.ms-windows.misc',
#  'comp.sys.ibm.pc.hardware',
#  'comp.sys.mac.hardware',
#  'comp.windows.x',
#  'misc.forsale',
#  'rec.autos',
#  'rec.motorcycles',
#  'rec.sport.baseball',
#  'rec.sport.hockey',
#  'sci.crypt',
#  'sci.electronics',
#  'sci.med',
#  'sci.space',
#  'soc.religion.christian',
#  'talk.politics.guns',
#  'talk.politics.mideast',
#  'talk.politics.misc',
#  'talk.religion.misc']

# %% [markdown]
# We can pick specific categories, and pull the relevant training and testing sets.

# %%
target_categories = ['talk.religion.misc', 'soc.religion.christian', 'sci.space', 'comp.graphics'] #Can change these of course

newsgroupsDF = pandas.DataFrame(columns = ['text', 'category', 'source_file'])
for category in target_categories:
    print("Loading data for: {}".format(category))
    ng = sklearn.datasets.fetch_20newsgroups(categories = [category], remove=['headers', 'footers', 'quotes'], data_home = '../data')
    newsgroupsDF = newsgroupsDF.append(pandas.DataFrame({'text' : ng.data, 'category' : [category] * len(ng.data), 'source_file' : ng.filenames}), ignore_index=True)
# Out:
# Loading data for: talk.religion.misc
# Loading data for: soc.religion.christian
# Loading data for: sci.space
# Loading data for: comp.graphics

# %% [markdown]
# Now we need to tokenize, and make a training and testing set:

# %%
newsgroupsDF['tokenized_text'] = newsgroupsDF['text'].apply(lambda x: lucem_illud_2020.word_tokenize(x))
newsgroupsDF['normalized_text'] = newsgroupsDF['tokenized_text'].apply(lambda x: lucem_illud_2020.normalizeTokens(x))

# %%
holdBackFraction = .2
train_ng_df, test_ng_df = lucem_illud_2020.trainTestSplit(newsgroupsDF, holdBackFraction=holdBackFraction)

# %%
print(len(train_ng_df))
print(len(test_ng_df))
# Out:
# 1723
# 430

# %% [markdown]
# We need to extract features from the text. We can use built-in feature extraction to do so. We will use a tf-idf vectorizer, which converts the document into a vector of words with tf-idf weights (term-frequency inverse-document frequency). This gives high weight to words that show up a lot in a given document, but rarely across documents in the corpus (more distinctive).

# %%
TFVectorizer_ng = sklearn.feature_extraction.text.TfidfVectorizer(max_df=100, min_df=2, stop_words='english', norm='l2')
TFVects_ng = TFVectorizer_ng.fit_transform(train_ng_df['text'])
train_ng_df['vect'] = [np.array(v).flatten() for v in TFVects_ng.todense()]

# %% [markdown]
# Now we can train the model:

# %%
MultinomialNB_ng = sklearn.naive_bayes.MultinomialNB()
MultinomialNB_ng.fit(np.stack(train_ng_df['vect'], axis = 0), train_ng_df['category'])
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %% [markdown]
# ...and save predictions to the dataframe:

# %%
train_ng_df['nb_predict'] = MultinomialNB_ng.predict(np.stack(train_ng_df['vect'], axis=0))
print("Training score:")
print(MultinomialNB_ng.score(np.stack(train_ng_df['vect'], axis=0), train_ng_df['category']))
# Out:
# Training score:
# 0.8908879860708068

# %%
train_ng_df[['category', 'nb_predict']][:10]
# Out:
#            category     nb_predict
# 1861  comp.graphics  comp.graphics
# 1699  comp.graphics  comp.graphics
# 1948  comp.graphics  comp.graphics
# 1684  comp.graphics  comp.graphics
# 1162      sci.space      sci.space
# 2039  comp.graphics  comp.graphics
# 2082  comp.graphics  comp.graphics
# 1692  comp.graphics  comp.graphics
# 1555      sci.space      sci.space
# 1771  comp.graphics  comp.graphics

# %% [markdown]
# Looks pretty good, lets examine the testing dataset:

# %%
#Create vectors
TFVects_test = TFVectorizer_ng.transform(test_ng_df['text'])
test_ng_df['vect'] = [np.array(v).flatten() for v in TFVects_test.todense()]

#Add to df
test_ng_df['nb_predict'] = MultinomialNB_ng.predict(np.stack(test_ng_df['vect'], axis=0))

#Test
print("Testing score:")
print(MultinomialNB_ng.score(np.stack(test_ng_df['vect'], axis=0), test_ng_df['category']))
# Out:
# Testing score:
# 0.7534883720930232

# %% [markdown]
# We can even use a confusion matrix, like we used last week for evaluating human coders relative to one another. Now we are evaluating our classifier relative to human coding. We'll just use the one in `lucem_illud_2020`, which requres a classifier and a dataframe with `'vect'` and `'category'` columns, like we have in the examples:

# %%
lucem_illud_2020.plotConfusionMatrix(MultinomialNB_ng, test_ng_df)

# %% [markdown]
# Let's calculate the precision, recall, and F-measures.

# %%
print(sklearn.metrics.precision_score(test_ng_df['nb_predict'], test_ng_df['category'], average = 'weighted')) #precision
print(sklearn.metrics.recall_score(test_ng_df['nb_predict'], test_ng_df['category'], average = 'weighted')) #recall
print(sklearn.metrics.f1_score(test_ng_df['nb_predict'], test_ng_df['category'], average = 'weighted')) #F-1 measure
# Out:
# 0.891291758433596
# 0.7534883720930232
# 0.7928443035206424

# %% [markdown]
# We can evaluate these per catagory. This has the same requiments as `plotConfusionMatrix`:

# %%
lucem_illud_2020.metrics.evaluateClassifier(MultinomialNB_ng, test_ng_df)
# Out:
#                         Error_Rate       AUC  Precision  Average_Precision  \
# Category
# soc.religion.christian    0.183721  0.856525   0.617801           0.601861
# comp.graphics             0.065116  0.943447   0.796610           0.773398
# talk.religion.misc        0.174419  0.592391   1.000000           0.359201
# sci.space                 0.069767  0.895152   0.913462           0.796931
#
#                           Recall
# Category
# soc.religion.christian  0.951613
# comp.graphics           0.959184
# talk.religion.misc      0.184783
# sci.space               0.818966

# %% [markdown]
# We can also plot the ROC curves. This has the same requiments as `plotConfusionMatrix`:

# %%
lucem_illud_2020.plotMultiROC(MultinomialNB_ng, test_ng_df)

# %% [markdown]
# And we can plot the PCA space visualization:

# %%
lucem_illud_2020.plotregions(MultinomialNB_ng, test_ng_df)
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# ...

# %% [markdown]
# ## <span style="color:red">*Exercise 2*</span>
#
# <span style="color:red">In the cells immediately following, perform Logistic and Naïve Bayes classification (binary or multinomial) using training, testing and extrapolation (uncoded) data from texts and hand-classifications associated with your final project (e.g., these could be crowd-sourced codes gathered through Amazon Mechanical Turk last week). Visualize the confusion matrix for training and testing sets. Calculate precision, recall, the F-measure, and AUC, then perform an ROC visualization. How do these classifiers perform? Exrapolate codes from these models to all uncoded data.

# %% [markdown]
# For my own project on nationalist sentiments in Chinese state media, I currently don't have enough hand-coded data to train the machine. So for this exercise and the exercises followed in this week's homework, I'm using a coded dataset I found on Kaggle. In the meanwhile this week, I'm trying to find whether there are datasets already available online that I can use for my own project. Or else, I will use Amazon Mechanical Turk to generate more responses (I have four annotators who coded the text for my last assignment).
#
# This is the description of the binary dataset: Sheet_1.csv contains 80 user responses, in the response_text column, to a therapy chatbot. Bot said: 'Describe a time when you have acted as a resource for someone else'.  User responded. If a response is 'not flagged', the user can continue talking to the bot. If it is 'flagged', the user is referred to help.

# %%
# dataset import
sheet_1 = pandas.read_csv(os.path.join(os.getcwd(), 'Sheet_1.csv'))
sheet_1.head()
# Out:
#   response_id        class                                      response_text  \
# 0  response_1  not_flagged              I try and avoid this sort of conflict
# 1  response_2      flagged  Had a friend open up to me about his mental ad...
# 2  response_3      flagged  I saved a girl from suicide once. She was goin...
# 3  response_4  not_flagged  i cant think of one really...i think i may hav...
# 4  response_5  not_flagged  Only really one friend who doesn't fit into th...
#
#   Unnamed: 3  Unnamed: 4 Unnamed: 5  Unnamed: 6 Unnamed: 7
# 0        NaN         NaN        NaN         NaN        NaN
# 1        NaN         NaN        NaN         NaN        NaN
# 2        NaN         NaN        NaN         NaN        NaN
# 3        NaN         NaN        NaN         NaN        NaN
# 4                    NaN        NaN         NaN        NaN

# %%
# Logistic 

# turn "class" column into a binary category varialbe True or False
sheet_1['category'] = [s == 'flagged' for s in sheet_1['class']]

# tokenize and normalize
sheet_1['tokenized_text'] = sheet_1['response_text'].apply(lambda x: lucem_illud_2020.word_tokenize(x))
sheet_1['normalized_text'] = sheet_1['tokenized_text'].apply(lambda x: lucem_illud_2020.normalizeTokens(x))

#split into training and testing dataset + holdbackfraction
holdBackFraction = .2
sheet1_train_data_df, sheet1_test_data_df = lucem_illud_2020.trainTestSplit(sheet_1, holdBackFraction=holdBackFraction)

#check length of dataframe - sample size of training and test dataset
print("sample size of training data:") 
print(len(sheet1_train_data_df))
print("sample size of test data:")
print(len(sheet1_test_data_df))

#logistic regression + L2 penalty
##turn into a tf-idf matrix

S1Vectorizer = sklearn.feature_extraction.text.TfidfVectorizer(max_df=100, min_df=2, stop_words='english', norm='l2')
S1Vects = S1Vectorizer.fit_transform(sheet1_train_data_df['response_text'])

S1Vects.shape
## save in a column 
sheet1_train_data_df['vect'] = [np.array(v).flatten() for v in S1Vects.todense()]

##fit transform

##flatten

## PCA and dimension reduction

pca = sklearn.decomposition.PCA()
sheet1_reduced_data = pca.fit_transform(np.stack(sheet1_train_data_df['vect'], axis=0))

sheet1_train_data_df['pca'] = [r for r in sheet1_reduced_data]
sheet1_train_data_df['pca_reduced_4'] = sheet1_train_data_df['pca'].apply(lambda x: x[:4])

# logistic regression model
logistic_l2 = sklearn.linear_model.LogisticRegression(penalty='l2')
logistic_l2.fit(np.stack(sheet1_train_data_df['pca_reduced_4'], axis=0), sheet1_train_data_df['category'])
print("training set score:")
print(logistic_l2.score(np.stack(sheet1_train_data_df['pca_reduced_4'], axis=0), sheet1_train_data_df['category']))

# on test data
##Create vectors
S1Vects_test = S1Vectorizer.transform(sheet1_test_data_df['response_text'])
sheet1_test_data_df['vect'] = [np.array(v).flatten() for v in S1Vects_test.todense()]

##PCA
sheet1_reduced_data_test = pca.transform(np.stack(sheet1_test_data_df['vect'], axis=0))
sheet1_test_data_df['pca'] = [r for r in sheet1_reduced_data_test]
sheet1_test_data_df['pca_reduced_4'] = sheet1_test_data_df['pca'].apply(lambda x: x[:4])

##Test
print("test set score:")
print(logistic_l2.score(np.stack(sheet1_test_data_df['pca_reduced_4'], axis=0), sheet1_test_data_df['category']))

#sheet1_test_data_df['vect'] = sheet1_test_data_df['pca_reduced_4']
# Out:
# sample size of training data:
# 64
# sample size of test data:
# 16
# training set score:
# 0.734375
# test set score:
# 0.5

# %%
sheet1_test_data_df['vect'] = sheet1_test_data_df['pca_reduced_4']

# %%
sheet1_test_data_df['logi_predict'] = logistic_l2.predict(np.stack(sheet1_test_data_df['vect'], axis=0))
print("Precision:")
print(sklearn.metrics.precision_score(sheet1_test_data_df['logi_predict'], sheet1_test_data_df['category']))
print("Recall:")
print(sklearn.metrics.recall_score(sheet1_test_data_df['logi_predict'], sheet1_test_data_df['category']))
print("F1:")
print(sklearn.metrics.f1_score(sheet1_test_data_df['logi_predict'], sheet1_test_data_df['category']))

##evaluating
print("testing data accuracy score:")
print(logistic_l2.score(np.stack(sheet1_test_data_df['vect'], axis=0), sheet1_test_data_df['category']))
print(lucem_illud_2020.evaluateClassifier(logistic_l2, sheet1_test_data_df))
lucem_illud_2020.plotConfusionMatrix(logistic_l2, sheet1_test_data_df)
lucem_illud_2020.plotregions(logistic_l2, sheet1_test_data_df)
lucem_illud_2020.plotMultiROC(logistic_l2, sheet1_test_data_df)
# Out:
# Precision:
# 0.0
# Recall:
# 0.0
# F1:
# 0.0
# testing data accuracy score:
# 0.5
#           Error_Rate  AUC  Precision  Average_Precision  Recall
# Category
# False            0.5  0.5        0.5                0.5     1.0
# True             0.5  0.5        0.0                0.5     0.0
# /Users/Tianyi/opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1439: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /Users/Tianyi/opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1439: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /Users/Tianyi/opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# ...

# %%
tree1 = sklearn.tree.DecisionTreeClassifier(max_depth=10,random_state=0)
tree1.fit(np.stack(sheet1_train_data_df['vect'], axis =0), sheet1_train_data_df['category'])

sheet1_test_data_df['tree_predict'] = tree1.predict(np.stack(sheet1_test_data_df['vect'], axis=0))
print("Precision:")
print(sklearn.metrics.precision_score(sheet1_test_data_df['tree_predict'], sheet1_test_data_df['category']))
print("Recall:")
print(sklearn.metrics.recall_score(sheet1_test_data_df['tree_predict'], sheet1_test_data_df['category']))
print("F1:")
print(sklearn.metrics.f1_score(sheet1_test_data_df['tree_predict'], sheet1_test_data_df['category']))

##evaluating
print("testing data accuracy score:")
print(tree1.score(np.stack(sheet1_test_data_df['vect'], axis=0), sheet1_test_data_df['category']))
print(lucem_illud_2020.evaluateClassifier(tree1, sheet1_test_data_df))
lucem_illud_2020.plotConfusionMatrix(tree1, sheet1_test_data_df)
lucem_illud_2020.plotregions(tree1, sheet1_test_data_df)
lucem_illud_2020.plotMultiROC(tree1, sheet1_test_data_df)

# %%
# Naive Bayes

naiveBayes_sheet1 = sklearn.naive_bayes.BernoulliNB()
naiveBayes_sheet1.fit(np.stack(sheet1_train_data_df['vect'], axis=0), sheet1_train_data_df['category'])

print("Training:")
print(naiveBayes_sheet1.score(np.stack(sheet1_train_data_df['vect'], axis=0), sheet1_train_data_df['category']))
print("Testing:")
print(naiveBayes_sheet1.score(np.stack(sheet1_test_data_df['vect'], axis=0), sheet1_test_data_df['category']))

sheet1_test_data_df['nb_predict'] = naiveBayes_sheet1.predict(np.stack(sheet1_test_data_df['vect'], axis=0))
sheet1_test_data_df['nb_predict_prob_true'] = naiveBayes_sheet1.predict_proba(np.stack(sheet1_test_data_df['vect'], axis=0))[:,0] #other is prop false

# all the measures
# precision
print("precision:")
print(sklearn.metrics.precision_score(sheet1_test_data_df['nb_predict'], sheet1_test_data_df['category']))
# recall
print("recall:")
print(sklearn.metrics.recall_score(sheet1_test_data_df['nb_predict'], sheet1_test_data_df['category']))
# f-1 measure
print("f-1 measure:")
print(sklearn.metrics.f1_score(sheet1_test_data_df['nb_predict'], sheet1_test_data_df['category']))

# conflusion matrix, evaluation, and ROC 
lucem_illud_2020.plotConfusionMatrix(naiveBayes_sheet1, sheet1_test_data_df)

print(lucem_illud_2020.evaluateClassifier(naiveBayes_sheet1, sheet1_test_data_df))

lucem_illud_2020.plotMultiROC(naiveBayes_sheet1, sheet1_test_data_df)
# Out:
# Training:
# 0.859375
# Testing:
# 0.6875
# precision:
# 0.375
# recall:
# 1.0
# f-1 measure:
# 0.5454545454545454
#           Error_Rate     AUC  Precision  Average_Precision  Recall
# Category
# False         0.3125  0.6875   0.615385           0.615385   1.000
# True          0.3125  0.6875   1.000000           0.687500   0.375

# %% [markdown]
# For my dataset, Naive Bayes is not doing well. Its error rate is high (above 0.30).

# %% [markdown]
# # Decision Trees

# %% [markdown]
# Decision trees can be used to predict both categorical/class labels (i.e., classification) and continuous labels (i.e., regression).

# %%
blobs_df = lucem_illud_2020.multiBlobs(noise=.2, centers=[(0,0), (0,5), (5,0), (-5,0), (0,-5)])
df_exampleTree_train, df_exampleTree_test = lucem_illud_2020.trainTestSplit(blobs_df)
lucem_illud_2020.plotter(df_exampleTree_train)
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# ...

# %% [markdown]
# Now we import our Decision Tree classifier from sklearn.tree (familiar syntax) and fit it using the fit method.

# %%
clf_tree = sklearn.tree.DecisionTreeClassifier(max_depth=4,random_state=0)
clf_tree.fit(np.stack(df_exampleTree_train['vect'], axis =0), df_exampleTree_train['category'])
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=4,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=0, splitter='best')

# %% [markdown]
# To see what's going on visually with the classification:

# %%
lucem_illud_2020.plotregions(clf_tree, df_exampleTree_train)
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# ...

# %%
lucem_illud_2020.evaluateClassifier(clf_tree, df_exampleTree_test)
# Out:
#           Error_Rate       AUC  Precision  Average_Precision    Recall
# Category
# 0              0.032  0.948874   0.898876           0.840553  0.919540
# 1              0.008  0.984448   0.990291           0.967997  0.971429
# 2              0.010  0.977035   0.988764           0.953774  0.956522
# 3              0.008  0.991728   0.974138           0.967593  0.991228
# 4              0.006  0.992585   0.980583           0.972969  0.990196

# %% [markdown]
# Lets look at accuracy:

# %%
sklearn.metrics.accuracy_score(df_exampleTree_test['category'],clf_tree.predict(np.stack(df_exampleTree_test['vect'], axis = 0)))
# Out:
# 0.968

# %% [markdown]
# What happens if we trim the tree?

# %%
depthvec = []
scorevec = []
for i in range(1,20):
    tree2 = sklearn.tree.DecisionTreeClassifier(max_depth=i,random_state=0)
    tree2.fit(np.stack(df_exampleTree_train['vect'], axis =0), df_exampleTree_train['category'])
    score = sklearn.metrics.accuracy_score(df_exampleTree_test['category'], tree2.predict(np.stack(df_exampleTree_test['vect'], axis = 0)))
    depthvec.append(i)
    scorevec.append(score)
plt.scatter(depthvec,scorevec)
plt.show()

# %% [markdown]
# We can select different layers of the decision tree or "prune" it. At approximately four layers down in the decision tree, the shape is somewhat odd, suggesting that our model is overfitting beyond those four layers.

# %% [markdown]
# Combining multiple overfitting estimators turns out to be a key idea in machine learning. This is called **bagging** and is a type of **ensemble** method. The idea is to make many randomized estimators--each can overfit, as decision trees are wont to do--but then to combine them, ultimately producing a better classification. A **random forest** is produced by bagging decision trees.

# %%
tree = sklearn.tree.DecisionTreeClassifier(max_depth=10) #Create an instance of our decision tree classifier.

bag = sklearn.ensemble.BaggingClassifier(tree, n_estimators=100, max_samples=0.8, random_state=1) #Each tree uses up to 80% of the data

# %%
bag.fit(np.stack(df_exampleTree_train['vect'], axis =0), df_exampleTree_train['category']) #Fit the bagged classifier
# Out:
# BaggingClassifier(base_estimator=DecisionTreeClassifier(class_weight=None,
#                                                         criterion='gini',
#                                                         max_depth=10,
#                                                         max_features=None,
#                                                         max_leaf_nodes=None,
#                                                         min_impurity_decrease=0.0,
#                                                         min_impurity_split=None,
#                                                         min_samples_leaf=1,
#                                                         min_samples_split=2,
#                                                         min_weight_fraction_leaf=0.0,
#                                                         presort=False,
#                                                         random_state=None,
# ...

# %%
lucem_illud_2020.plotregions(bag, df_exampleTree_test)
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# ...

# %%
lucem_illud_2020.evaluateClassifier(bag, df_exampleTree_test)
# Out:
#           Error_Rate       AUC  Precision  Average_Precision    Recall
# Category
# 0              0.040  0.925886   0.894118           0.803068  0.873563
# 1              0.010  0.986679   0.971698           0.957190  0.980952
# 2              0.008  0.986679   0.978261           0.960994  0.978261
# 3              0.014  0.981661   0.965217           0.945817  0.973684
# 4              0.008  0.987684   0.980392           0.965169  0.980392

# %%
lucem_illud_2020.plotConfusionMatrix(bag, df_exampleTree_test)

# %% [markdown]
# ## <span style="color:red">*Exercise 3*</span>
#
# <span style="color:red">In the cells immediately following, perform decision tree and random forest classification (binary, multinomial or continuous) using training, testing and extrapolation (uncoded) data from texts and hand-classifications associated with your final project. As with ***Exercise 2***, these could be crowd-sourced codes gathered through Amazon Mechanical Turk last week. Visualize the classification of data points. Calculate relevant metrics (e.g., precision, recall, the F-measure, and AUC). Now build an ensemble classifier by bagging trees into a random forest. Visualize the result. How do these classifiers perform? What does ensemble learning do?

# %%
#decision tree

tree1 = sklearn.tree.DecisionTreeClassifier(max_depth=10,random_state=0)
tree1.fit(np.stack(sheet1_train_data_df['vect'], axis =0), sheet1_train_data_df['category'])

sheet1_test_data_df['tree_predict'] = tree1.predict(np.stack(sheet1_test_data_df['vect'], axis=0))
print("Precision:")
print(sklearn.metrics.precision_score(sheet1_test_data_df['tree_predict'], sheet1_test_data_df['category']))
print("Recall:")
print(sklearn.metrics.recall_score(sheet1_test_data_df['tree_predict'], sheet1_test_data_df['category']))
print("F1:")
print(sklearn.metrics.f1_score(sheet1_test_data_df['tree_predict'], sheet1_test_data_df['category']))

##evaluating
print("testing data accuracy score:")
print(tree1.score(np.stack(sheet1_test_data_df['vect'], axis=0), sheet1_test_data_df['category']))
print(lucem_illud_2020.evaluateClassifier(tree1, sheet1_test_data_df))
lucem_illud_2020.plotConfusionMatrix(tree1, sheet1_test_data_df)
lucem_illud_2020.plotregions(tree1, sheet1_test_data_df)
lucem_illud_2020.plotMultiROC(tree1, sheet1_test_data_df)
# Out:
# Precision:
# 0.42857142857142855
# Recall:
# 0.5
# F1:
# 0.4615384615384615
# testing data accuracy score:
# 0.5625
#           Error_Rate       AUC  Precision  Average_Precision    Recall
# Category
# False         0.4375  0.547619        0.6           0.587500  0.666667
# True          0.4375  0.547619        0.5           0.464286  0.428571
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
# bagging trees into a random forest
tree2 = sklearn.tree.DecisionTreeClassifier(max_depth=10)
sheet1_bag = sklearn.ensemble.BaggingClassifier(tree2, n_estimators=100, max_samples=0.8, random_state=1) #Each tree uses up to 80% of the data
sheet1_bag.fit(np.stack(sheet1_train_data_df['vect'], axis =0), sheet1_train_data_df['category']) #Fit the bagged classifier

sheet1_test_data_df['bag_predict'] = sheet1_bag.predict(np.stack(sheet1_test_data_df['vect'], axis=0))
print("Precision:")
print(sklearn.metrics.precision_score(sheet1_test_data_df['bag_predict'], sheet1_test_data_df['category']))
print("Recall:")
print(sklearn.metrics.recall_score(sheet1_test_data_df['bag_predict'], sheet1_test_data_df['category']))
print("F1:")
print(sklearn.metrics.f1_score(sheet1_test_data_df['bag_predict'], sheet1_test_data_df['category']))

##evaluating
print("testing data accuracy score:")
print(sheet1_bag.score(np.stack(sheet1_test_data_df['vect'], axis=0), sheet1_test_data_df['category']))
print(lucem_illud_2020.evaluateClassifier(sheet1_bag, sheet1_test_data_df))
lucem_illud_2020.plotConfusionMatrix(sheet1_bag, sheet1_test_data_df)
lucem_illud_2020.plotregions(sheet1_bag, sheet1_test_data_df)
lucem_illud_2020.plotMultiROC(sheet1_bag, sheet1_test_data_df)
# Out:
# Precision:
# 0.2857142857142857
# Recall:
# 0.6666666666666666
# F1:
# 0.4
# testing data accuracy score:
# 0.625
#           Error_Rate       AUC  Precision  Average_Precision    Recall
# Category
# False          0.375  0.587302   0.615385           0.609509  0.888889
# True           0.375  0.587302   0.666667           0.502976  0.285714
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %% [markdown]
# It is notable that ensemble learning in the case of building a random forest with bagging improves the performance (error rate decreases from 0.44 to 0.375; AUC goes up from 0.547 to 0.587). However, both models still have a significant error rate and neither do well.

# %% [markdown]
# # K-Nearest Neighbors

# %% [markdown]
# The K-Nearest neighbors classifier takes a simpler premise than those before: Find the closest labeled datapoint in set and "borrow" its label.
#
# Let's use newsgroup data again.

# %%
newsgroupsDF[:5]
# Out:
#                                                 text            category  \
# 0  \n\nParadise and salvation are not the same th...  talk.religion.misc
# 1  \nYou're admitting a lot more than that.  You ...  talk.religion.misc
# 2  \n\nJesus also recognized other holy days, lik...  talk.religion.misc
# 3  In <lsjc8cINNmc1@saltillo.cs.utexas.edu> turpi...  talk.religion.misc
# 4  \nI'm sorry, but He does not!  Ever read the F...  talk.religion.misc
#
#                                          source_file  \
# 0  ../data/20news_home/20news-bydate-train/talk.r...
# 1  ../data/20news_home/20news-bydate-train/talk.r...
# 2  ../data/20news_home/20news-bydate-train/talk.r...
# 3  ../data/20news_home/20news-bydate-train/talk.r...
# 4  ../data/20news_home/20news-bydate-train/talk.r...
#
#                                       tokenized_text  \
# 0  [Paradise, and, salvation, are, not, the, same...
# 1  [You, 're, admitting, a, lot, more, than, that...
# ...

# %% [markdown]
# Make a testing and training set:

# %%
holdBackFraction = .2
train_ng_df, test_ng_df = lucem_illud_2020.trainTestSplit(newsgroupsDF, holdBackFraction=holdBackFraction)

# %% [markdown]
# Let's initialize our k-nearest neighbors classifier:

# %%
n_neighbors = 15
weights="uniform"
clf_knearest = sklearn.neighbors.KNeighborsClassifier(n_neighbors, weights=weights)

# %% [markdown]
# Let's try to classify using the TF-IDF vectors:

# %%
TFVectorizer_ng = sklearn.feature_extraction.text.TfidfVectorizer(max_df=100, min_df=2, stop_words='english', norm='l2')
TFVects_ng = TFVectorizer_ng.fit_transform(train_ng_df['text'])
train_ng_df['vect'] = [np.array(v).flatten() for v in TFVects_ng.todense()]

# %%
clf_knearest.fit(np.stack(train_ng_df['vect'], axis = 0), train_ng_df['category'])
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=15, p=2,
#                      weights='uniform')

# %%
lucem_illud_2020.evaluateClassifier(clf_knearest, train_ng_df)
# Out:
#                         Error_Rate       AUC  Precision  Average_Precision  \
# Category
# soc.religion.christian    0.278584  0.504132   1.000000           0.286848
# comp.graphics             0.320952  0.664876   0.444118           0.382748
# talk.religion.misc        0.316889  0.580606   0.254000           0.207933
# sci.space                 0.267557  0.685546   0.500928           0.404183
#
#                           Recall
# Category
# soc.religion.christian  0.008264
# comp.graphics           0.633124
# talk.religion.misc      0.423333
# sci.space               0.584416

# %% [markdown]
# And lets look at the testing data

# %%
#Create vectors
TFVects_test = TFVectorizer_ng.transform(test_ng_df['text'])
test_ng_df['vect'] = [np.array(v).flatten() for v in TFVects_test.todense()]

#Add to df
test_ng_df['nb_predict'] = clf_knearest.predict(np.stack(test_ng_df['vect'], axis=0))

#Test
print("Testing score:")
print(clf_knearest.score(np.stack(test_ng_df['vect'], axis=0), test_ng_df['category']))
# Out:
# Testing score:
# 0.2813953488372093

# %% [markdown]
# Let's produce another confusion matrix:

# %%
lucem_illud_2020.plotConfusionMatrix(clf_knearest, test_ng_df)

# %% [markdown]
# You can produce the PCA space visual if you want, altough it can take a very long time, so we'll leave it optionally commented out:

# %%
#lucem_illud_2020.plotregions(clf_knearest, test_ng_df)

# %% [markdown]
# ## <span style="color:red">*Exercise 4*</span>
#
# <span style="color:red">In the cells immediately following, perform and visualize k-nearest neighbor classification using training, testing and extrapolation (uncoded) data from texts and hand-classifications associated with your final project. Visualize the classification of data points and calculate relevant metrics (e.g., precision, recall, the F-measure, and AUC). Articulate how the *k*-nearest neighbor approach relates to *k*-means clustering explored in ***week 3***?

# %%
## K-nearest neighbor
n_neighbors = 10
weights="uniform"
knearest1 = sklearn.neighbors.KNeighborsClassifier(n_neighbors, weights=weights)
knearest1.fit(np.stack(sheet1_train_data_df['vect'], axis = 0), sheet1_train_data_df['category'])
sheet1_test_data_df['knearest_predict'] = knearest1.predict(np.stack(sheet1_test_data_df['vect'], axis=0))

print("Precision:")
print(sklearn.metrics.precision_score(sheet1_test_data_df['knearest_predict'], sheet1_test_data_df['category']))
print("Recall:")
print(sklearn.metrics.recall_score(sheet1_test_data_df['knearest_predict'], sheet1_test_data_df['category']))
print("F1:")
print(sklearn.metrics.f1_score(sheet1_test_data_df['knearest_predict'], sheet1_test_data_df['category']))

##evaluating
print("testing data accuracy score:")
print(knearest1.score(np.stack(sheet1_test_data_df['vect'], axis=0), sheet1_test_data_df['category']))
print(lucem_illud_2020.evaluateClassifier(knearest1, sheet1_test_data_df))
lucem_illud_2020.plotConfusionMatrix(knearest1, sheet1_test_data_df)

lucem_illud_2020.plotMultiROC(knearest1, sheet1_test_data_df)
# Out:
# Precision:
# 0.0
# Recall:
# 0.0
# F1:
# 0.0
# testing data accuracy score:
# 0.5625
#           Error_Rate  AUC  Precision  Average_Precision  Recall
# Category
# False         0.4375  0.5     0.5625             0.5625     1.0
# True          0.4375  0.5     0.0000             0.4375     0.0
# /Users/Tianyi/opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1439: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /Users/Tianyi/opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1439: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /Users/Tianyi/opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
# ...

# %% [markdown]
# # SVMs
#
# Now we will examine Support Vector Machines, an approach that creates the partition that preserves the "maximum margin" between classes.
#
# We will use a few sub forums from reddit--which tend to share text rather than memes--namely `talesfromtechsupport`, `badroommates`, `weeabootales` and `relationships`. The top 100 text posts from each have been saved to `data/reddit.csv`.

# %%
redditDf = pandas.read_csv('../data/reddit.csv', index_col = 0)

#Drop a couple missing values

redditDf = redditDf.dropna()

#Set category

redditDf['category'] = redditDf['subreddit']

#tokenize and normalize
redditDf['tokenized_text'] = redditDf['text'].apply(lambda x: lucem_illud_2020.word_tokenize(x))
redditDf['normalized_text'] = redditDf['tokenized_text'].apply(lambda x: lucem_illud_2020.normalizeTokens(x))

# %% [markdown]
# We will tf.idf the data to make our vectors:

# %%
redditTFVectorizer = sklearn.feature_extraction.text.TfidfVectorizer(max_df=0.5, min_df=3, stop_words='english', norm='l2')
redditTFVects = redditTFVectorizer.fit_transform([' '.join(l) for l in redditDf['normalized_text']])
redditDf['vect'] = [np.array(v).flatten() for v in redditTFVects.todense()]

# %% [markdown]
# Initilize the model and make a train test split:

# %%
holdBackFraction = .2
train_redditDf, test_redditDf = lucem_illud_2020.trainTestSplit(redditDf, holdBackFraction=holdBackFraction)

# %%
clf_svm = sklearn.svm.SVC(kernel='linear', probability = False)
#probability = True is slower but  lets you call predict_proba()
clf_svm.fit(np.stack(train_redditDf['vect'], axis=0), train_redditDf['category'])
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#     kernel='linear', max_iter=-1, probability=False, random_state=None,
#     shrinking=True, tol=0.001, verbose=False)

# %% [markdown]
# ...and consider the results:

# %%
lucem_illud_2020.evaluateClassifier(clf_svm, test_redditDf)
# Out:
#                                                     Error_Rate       AUC  \
# Category
# Weeaboo Tales: stories about the extreme fans o...    0.006270  0.991857
# Bad Roommates: Tales of Irritation                    0.025078  0.971829
# Relationships                                         0.025078  0.951898
# Tales From Tech Support                               0.012539  0.987573
#
#                                                     Precision  \
# Category
# Weeaboo Tales: stories about the extreme fans o...   0.987952
# Bad Roommates: Tales of Irritation                   0.943182
# Relationships                                        0.968750
# Tales From Tech Support                              0.964286
#
#                                                     Average_Precision  \
# Category
# Weeaboo Tales: stories about the extreme fans o...           0.979184
# Bad Roommates: Tales of Irritation                           0.919685
# ...

# %%
lucem_illud_2020.plotConfusionMatrix(clf_svm, test_redditDf)

# %%
lucem_illud_2020.plotregions(clf_svm, test_redditDf)
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# ...

# %% [markdown]
# # Neural Nets
#
# We include an example of a simple neural network, the Multi-layer Perceptron (MLP) that learns a function $f(\cdot): R^m \rightarrow R^o$ by training on a dataset, where $m$ is the number of dimensions for input and $o$ is the number of dimensions for output. Given a set of features $X = {x_1, x_2, ..., x_m}$ and a target $y$, it can learn a non-linear function approximator for either classification or regression. It is different from logistic regression, in that between the input and the output layer, there can be one or more non-linear layers, called hidden layers. The following figure shows a one hidden layer MLP with scalar output. ![title](../data/multilayerperceptron_network.png) The leftmost layer, known as the input layer, consists of a set of "neurons" $\{x_i | x_1, x_2, ..., x_m\}$ representing the input features (e.g., weighted words). Each neuron in the hidden layer transforms the values from the previous layer with a weighted linear summation $w_1x_1 + w_2x_2 + ... + w_mx_m$, followed by a non-linear activation function $g(\cdot):R \rightarrow R$ - like the logistic or hyperbolic tan function. The output layer receives the values from the last hidden layer and transforms them into output values.

# %%
clf_nn = sklearn.neural_network.MLPClassifier()
clf_nn.fit(np.stack(train_redditDf['vect'], axis=0), train_redditDf['category'])
# Out:
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#               beta_2=0.999, early_stopping=False, epsilon=1e-08,
#               hidden_layer_sizes=(100,), learning_rate='constant',
#               learning_rate_init=0.001, max_iter=200, momentum=0.9,
#               n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#               random_state=None, shuffle=True, solver='adam', tol=0.0001,
#               validation_fraction=0.1, verbose=False, warm_start=False)

# %%
lucem_illud_2020.evaluateClassifier(clf_nn, test_redditDf)
# Out:
#                                                     Error_Rate       AUC  \
# Category
# Weeaboo Tales: stories about the extreme fans o...    0.015674  0.977690
# Bad Roommates: Tales of Irritation                    0.025078  0.964492
# Relationships                                         0.031348  0.958636
# Tales From Tech Support                               0.009404  0.989683
#
#                                                     Precision  \
# Category
# Weeaboo Tales: stories about the extreme fans o...   0.975610
# Bad Roommates: Tales of Irritation                   0.964286
# Relationships                                        0.914286
# Tales From Tech Support                              0.975904
#
#                                                     Average_Precision  \
# Category
# Weeaboo Tales: stories about the extreme fans o...           0.949751
# Bad Roommates: Tales of Irritation                           0.923897
# ...

# %%
lucem_illud_2020.plotConfusionMatrix(clf_nn, test_redditDf)

# %%
lucem_illud_2020.plotregions(clf_nn, test_redditDf)
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# ...

# %% [markdown]
# It performs very well.

# %% [markdown]
# ## <span style="color:red">*Exercise 5*</span>
#
# <span style="color:red">In the cells immediately following, perform a neural network classification and calculate relevant metrics (e.g., precision, recall, the F-measure, and AUC). How does this classify relevant to *k*-nearest neighbor, Naive Bayes, logistic and decision-tree approaches?

# %%
## neural networks
nn = sklearn.neural_network.MLPClassifier()
nn.fit(np.stack(sheet1_train_data_df['vect'], axis=0), sheet1_train_data_df['category'])
sheet1_test_data_df['nn_predict'] = nn.predict(np.stack(sheet1_test_data_df['vect'], axis=0))

print("Precision:")
print(sklearn.metrics.precision_score(sheet1_test_data_df['nn_predict'], sheet1_test_data_df['category']))
print("Recall:")
print(sklearn.metrics.recall_score(sheet1_test_data_df['nn_predict'], sheet1_test_data_df['category']))
print("F1:")
print(sklearn.metrics.f1_score(sheet1_test_data_df['nn_predict'], sheet1_test_data_df['category']))

##evaluating
print("testing data accuracy score:")
print(nn.score(np.stack(sheet1_test_data_df['vect'], axis=0), sheet1_test_data_df['category']))
print(lucem_illud_2020.evaluateClassifier(nn, sheet1_test_data_df))
lucem_illud_2020.plotConfusionMatrix(nn, sheet1_test_data_df)
lucem_illud_2020.plotregions(nn, sheet1_test_data_df)
lucem_illud_2020.plotMultiROC(nn, sheet1_test_data_df)
# Out:
# /Users/Tianyi/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Precision:
# 0.2857142857142857
# Recall:
# 0.3333333333333333
# F1:
# 0.30769230769230765
# testing data accuracy score:
# 0.4375
#           Error_Rate       AUC  Precision  Average_Precision    Recall
# Category
# False         0.5625  0.420635   0.500000           0.527778  0.555556
# True          0.5625  0.420635   0.333333           0.407738  0.285714
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# ...
